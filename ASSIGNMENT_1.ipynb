# %% [markdown]
# #DATA ANALYTICS QUESTIONS ANSWERS

# %% [markdown]
# 1. Define the role of a data analyst in your own words. What value do they bring to an organization?
#    - The role of a data analyst is to examining raw data to discover patters , making insights to support decision making.
#    - They help organisations to make evidence based decisions.
#    - They make complex data easier to understand for making decisions.
#    - They analyse the organization sales or reports appropriatelty for making insights.
#    - After reviewing insights organizaton can make batter complex decisions in easier way.
# 2. List three tools commonly used by data analysts and explain what each is mainly used for?
#    - EXCEL Used by data analysts for making raw data in patters and create in sequence.
#    - SQL used by data analysts to query and manage data in relational databases, retrieving,analyzing, and manupulating databases.
#    - Python is a language which is flexible for data manipulation,visualization, and machine learning tasks.
# 3. Write the end-to-end analytics workflow in the correct order and briefly explain each step.
#    - PROBLEM FINDING - This step involves finding problems related to business in the purpose of solving them.
#    - DATA COLLECTION - It involves identification of data relevant to problem and gathered from various internal and external sources.
#    - DATA CLEANING - This step involves cleaning, arranging and transforming the data in usable format.
#    - DATA MODELING - This tep involes making data in model or charts form for gaining dezired insights.
#    - DEPLOYMENT AND REPORTING - The Final results and sights are communicated to stakeholders in a clear ,understanable manner.
# 4. What is prompt engineering, and explain any two types of prompts used in Gen. AI?
#   - It is the process of structuring or crafting an instruction in order to produce better outputs from a generative artificial intelligence model.
#   - zero-shot prompt - Give the AI a  direct instructions or question without any examples.
#   - Few-Shot - Provide the AI with one a ewexamples of the desired output style,format or tone.
# 5. What are the key differences between a business analyst and data analyst in terms of role, responsibilities and focus?
#   - DATA ANALYST;;
#
#   - The role is to transform data into actionable insights that hels other to understand and make inform decisions.
#   - Responsibilities are to collect, clean, analyse data, interpret data, create reports and commnicable insights.
#   - Data Analyst focus on extracting hihlights from raw data.
#   - Business Analyst;;
#
#   - Role is to help the business make informed decisions and grow by solving the right problems.
#   - Responsibilities are to gathering,analysing,developing,create business cases, communicate with stake holders, collaborate with stake holders to implement solutions.
#   - It focuses on understanding business needs and using data to help solve problems.
# 6. Explain any three AI-powered ETL(Extract,Transform,Load) tools and how they are used in analytics?
#   - AZURE DATA FACTORY;;
#   - It provide a low code visual environment with AI capabilities for data integration.It automates the movement and transformation of data on large scale, making it easier for users to build schedule, and orchestrate data pipelines without extensive coding.
#   - USE IN ANALYTICS
#   - It can improve the efficiency and speed of getting data ready for analysis in services like Power BI.
#   - Talend (by Qlik);;
#   - It uses AIv and machine learning to improve data quality and trustworthiness.
#   - USE IN ANALYTICS
#   - This feature help ensure the data being used for analytics is accurate and reliable.
#   - AWS GLUE;;
#   - It is a server less ETL service that uses AI to automate data  discovery and preparation.
#   - USE IN ANALYTICS
#   - The AI-powered data cataloging and automatic schema discovery in glue significantly reduce the time it takes to prepare data for analytics.
# 7. Give three applications of data analytics across different industries and explain how it creates value.
#   - RETAIL
#   - It Creates value by analyzing customer purchase history, browsing patterns, demographics and interaction across various channels (online, instore, socialmedia ). it gives targeted product recommendations, potimizing pricing strategies.
#
#   - HEALTHCARE
#   - Itcreates value by improve patient outcomes by enabling early intervention and personalized care .
#
#   - BANKING AND FINANCE
#   - It creates value by minimize financial losses due to fraud, mitigate credit and operational risks, and ensure compliance with regulatory requirements.
# 8. Explain the evolutiuon of analytics, highlighting the different stages from Descriptive to Generative AI.
#    - The stages are generally categorised in to descriptive, diagnostic, predictive, prescriptive.
#    - DESCRIPTIVE ''
#    - It focuses on understanding past events by summarizing historical data.
#    - DIAGNOSTIC
#    - This step aims to understand the root causes of past occurences.
#    - PREDICTIVE ''
#    - This step aims to forecast future trends and outcomes by analysis of past occurrences.
#    - PRESCRIPTIVE ''
#    - It goes beyond forecasting to recommend specific actions to achieve desired outcomes.
